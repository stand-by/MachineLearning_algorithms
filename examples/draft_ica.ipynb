# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

# %%
sig1 = np.sin(np.linspace(0,20,200))
sig2 = np.sinc(np.linspace(0,200,200))
plt.plot(sig1)
plt.plot(sig2)
