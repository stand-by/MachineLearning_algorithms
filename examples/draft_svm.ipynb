# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import svm

# %%
dataset = np.loadtxt("datasets/svm_dataset1.csv",delimiter=',')
X,y = dataset[:,:2],dataset[:,2]

pos = np.array([X[i] for i in xrange(X.shape[0]) if y[i] == 1])
neg = np.array([X[i] for i in xrange(X.shape[0]) if y[i] == 0])

def plot_data():
    plt.figure(figsize=(10,6))
    plt.plot(pos[:,0],pos[:,1],'k+',label='Positive Sample')
    plt.plot(neg[:,0],neg[:,1],'yo',label='Negative Sample')
    plt.legend()
def plot_boundary(my_svm, xmin, xmax, ymin, ymax):
    xvals = np.linspace(xmin,xmax,1000)
    yvals = np.linspace(ymin,ymax,1000)
    zvals = np.zeros((len(xvals),len(yvals)))
    for i in xrange(len(xvals)):
        for j in xrange(len(yvals)):
            zvals[i][j] = float(my_svm.predict(np.array([[xvals[i],yvals[j]]])))
    zvals = zvals.transpose()

    u, v = np.meshgrid( xvals, yvals )
    mycontour = plt.contour( xvals, yvals, zvals, [0])
    plt.title("Decision Boundary")
plot_data()

# %%
squared_dist = lambda x,y: np.sum((x-y)**2)
def linear_kernel(x, l):
    return np.dot(x,l.T)
def rbf(x, l, gamma=0.1):
    x = np.atleast_2d(x)
    l = np.atleast_2d(l)
    return np.exp(-gamma * squared_dist(x, l)).flatten() 
#remove .flatten()

# %%
linear_svm = svm.SVC(C=1, kernel=linear_kernel)
linear_svm.fit(X,y)
plot_data()
plot_boundary(linear_svm,0,5,0,5)

# %%
dataset = np.loadtxt("datasets/svm_dataset2.csv",delimiter=',')
X,y = dataset[:,:2],dataset[:,2]

pos = np.array([X[i] for i in xrange(X.shape[0]) if y[i] == 1])
neg = np.array([X[i] for i in xrange(X.shape[0]) if y[i] == 0])

gaus_svm = svm.SVC(C=1, kernel='rbf', gamma=100)
gaus_svm.fit(X,y)
plot_data()
plot_boundary(gaus_svm,0,1,0,1)
gaus_svm2 = svm.SVC(C=1, kernel='rbf', gamma=10000)
gaus_svm2.fit(X,y)
plot_boundary(gaus_svm2,0,1,0,1)

# %%
dataset = np.loadtxt("datasets/svm_dataset3.csv",delimiter=',')
X,y = dataset[:,:2],dataset[:,2]

pos = np.array([X[i] for i in xrange(X.shape[0]) if y[i] == 1])
neg = np.array([X[i] for i in xrange(X.shape[0]) if y[i] == 0])

gaus_svm = svm.SVC(C=1, kernel='rbf', gamma=100)
gaus_svm.fit(X,y)
plot_data()
plot_boundary(gaus_svm,-.5,.3,-.8,.6)
